# %%
import requests
import urllib
import IPython.display as ipd
from bs4 import BeautifulSoup
import json
from gtts import gTTS

# %%
def printtts(text):
     tts = gTTS(text= text, lang = 'ko')
     tts.save('output.mp3')
     ipd.display(ipd.Audio('output.mp3', autoplay = True))

# %%
def get_answer(text, sessionId):
    data_send = {
        'query': text, 'sessionId': sessionId,
        'lang': 'ko', 'timezone' : 'Asia/Seoul'
    }
    data_header = {
        'Authorization': 'Bearer aaa7c45b4cc248a0a795802a5cf62273',
        'Content-Type': 'application/json; charset=utf-8'
    }

    dialogflow_url = 'https://api.dialogflow.com/v1/query?v=20150910'
    res = requests.post(dialogflow_url, data=json.dumps(data_send), headers=data_header)
    if res.status_code == requests.codes.ok:
       return res.json()    
    return {}

# %%
dict = get_answer("짜장면 2개, 짬뽕 5개 주세요", 'user01')
answer = dict['result']['fulfillment']['speech']
print("Bot:" + answer)
# Out:
# Bot:짜장면 2, 짬뽕 5 확인

# %%
print(dict['result']['metadata']['intentName'])
print(dict['result']['actionIncomplete'])
params = dict['result']['parameters']
for p in params :
    print(p, params[p])
# Out:
# order2
# False
# food_number [{'food': '짜장면', 'number-integer': 2.0}, {'food': '짬뽕', 'number-integer': 5.0}]

# %%
txt = "1"

print("종료를 원하시면, 0을 입력하시오.")

while(txt!="0"):
    txt = input("->")
    dict = get_answer(txt, 'user01')
    answer = dict['result']['fulfillment']['speech'] 

    #첫번째 인텐트
    if dict['result']['metadata']['intentName'] == 'order2' :
        price = {"짜장면":5000, "짬뽕":10000, "탕수육":20000}
        params = dict['result']['parameters']['food_number']
        
        #get함수는 dictionary 값을 받아오는것
        #a{"i":6}이 있으면, a.get(i) == a["i"]와 같다. a["hh"] 면 오류가 나고, a.get("hh")면 None값을 반환한다.
        #a.get("hh", 1)은, 값이 없는 모든 키에 대해, 1값을 넣어준다는 의미이다.
        
        output = [  food.get("number-integer", 1)*price[food["food"]]  for food in params ] 
        print(sum(output))
     
     #두번째 인텐트
    elif dict['result']['metadata']['intentName'] == 'weather' and  dict['result']['actionIncomplete'] == False :        
            date = dict['result']['parameters']['date']
            geo_city = dict['result']['parameters']['geo-city']                    
            
            info = getWeather(geo_city)            
            print(f"{geo_city} 날씨 정보 : {info['temp']} /  {info['desc']}")
            #print("날씨 ", date, geo_city)       
    else :
        print("Bot:" + answer)
# Out:
# 종료를 원하시면, 0을 입력하시오.
# ->0
# Bot:방금 하신 말씀을 잘 못 알아들었어요.

# %%
txt = "1"

print("종료를 원하시면, 0을 입력하시오.")

while(txt!="0"):
    txt = input("->")
    dict = get_answer(txt, 'user01')
    answer = dict['result']['fulfillment']['speech']
    print("Bot:" + answer)
# Out:
# 종료를 원하시면, 0을 입력하시오.
# ->0
# Bot:제가 제대로 이해하고 있는지 잘 모르겠어요.

# %%
res = requests.get("https://search.naver.com/search.naver?query=%EB%8C%80%EA%B5%AC%EB%82%A0%EC%94%A8")
print(res)
print(type(res))
print(res.text)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# ...

# %%
#requests.post(dialogflow_url, data=json.dumps(data_send), headers=data_header)

# %%
data_send = {
        'query': 'hello', 
        'sessionId': 'user01',
        'lang': 'ko',
        'timezone' : 'Asia/Seoul'
    }

json.dumps(data_send)
# Out:
# '{"query": "hello", "sessionId": "user01", "lang": "ko", "timezone": "Asia/Seoul"}'

# %%
data_send = {
        'query': '오늘 부산 날씨 어때', 'sessionId': 'user01',
        'lang': 'ko', 'timezone' : 'Asia/Seoul'
}
data_header = {
        'Authorization': 'Bearer aaa7c45b4cc248a0a795802a5cf62273',
        'Content-Type': 'application/json; charset=utf-8'
}

dialogflow_url = 'https://api.dialogflow.com/v1/query?v=20150910'
res = requests.post(dialogflow_url,
                    data=json.dumps(data_send), 
                    headers=data_header)

# %%
print(res)    
print(res.text)
a = res.json()   # res.dumps
print(type(a))
# Out:
# <Response [200]>
# {
#   "id": "2ecc264f-6b23-44d9-8c56-b8a8a43594db-ce609cdc",
#   "lang": "ko",
#   "sessionId": "user01",
#   "timestamp": "2020-02-06T06:46:19.267Z",
#   "result": {
#     "source": "agent",
#     "resolvedQuery": "오늘 부산 날씨 어때",
#     "action": "",
#     "actionIncomplete": false,
#     "score": 1.0,
#     "parameters": {
#       "date-time": "2020-02-06",
#       "geo-city": "부산광역시"
#     },
#     "contexts": [
#       {
#         "name": "__system_counters__",
#         "lifespan": 1,
#         "parameters": {
#           "no-input": 0.0,
#           "no-match": 0.0,
#           "food_number": [
#             {
#               "food": "짜장면",
#               "food.original": "짜장면",
#               "number-integer": 2.0,
#               "number-integer.original": "2"
#             },
#             {
#               "food": "짬뽕",
#               "food.original": "짬뽕",
#               "number-integer": 5.0,
#               "number-integer.original": "5"
# ...

# %%
data = [{'number-integer': 2.0, 'food': '짜장면'}, {'number-integer': 5.0, 'food': '짬뽕'}]
data = [{'food': '짜장면'}, {'number-integer': 5.0, 'food': '짬뽕'}]

price = {"짜장면":5000, "짬뽕":10000, "탕수육":20000}
output = [  food.get("number-integer", 1)*price[food["food"]]   for food in data  ] 

print(sum(output))
# Out:
# 55000.0

# %%
url = "https://search.naver.com/search.naver?query=%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C%EB%82%A0%EC%94%A8"
res = requests.get(url)
html = res.text 
print(html)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="부산광역시날씨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'부산광역시날씨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'부산광역시날씨'의 네이버 통합검색 결과입니다."> <title>부산광역시날씨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css"> <link rel="stylesheet" type="t
# ...

# %%
html = urllib.request.urlopen(url).read()
print(html)
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xeb\xb6\x80\xec\x82\xb0\xea\xb4\x91\xec\x97\xad\xec\x8b\x9c\xeb\x82\xa0\xec\x94\xa8 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xeb\xb6\x80\xec\x82\xb0\xea\xb4\x91\xec\x97\xad\xec\x8b\x9c\xeb\x82\xa0\xec\x94\xa8\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xed\x86\xb5\xed\x95\xa9\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xeb\xb6\x80\xec\x82\xb0\xea\xb4\x91\xec\x97\xad\xec\x8b\x9c\xeb\x82\xa0\xec\x94\xa8\'\x
# ...

# %%
bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
bs = BeautifulSoup(requests.get(url).text, "html.parser")
print(bs.html)
# Out:
# <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="부산광역시날씨 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'부산광역시날씨'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'부산광역시날씨'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>부산광역시날씨 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstati
# ...

# %%
city = "부산광역시"
url = "https://search.naver.com/search.naver?query="
url = url + urllib.parse.quote_plus(city + "날씨")
print(url)
# Out:
# https://search.naver.com/search.naver?query=%EB%B6%80%EC%82%B0%EA%B4%91%EC%97%AD%EC%8B%9C%EB%82%A0%EC%94%A8

# %%
bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")

# %%
temp = bs.findAll("span", "todaytemp")
desc = bs.findAll("p", "cast_txt")
print(temp[0].text) 
print(desc[0].text)
# Out:
# 6
# 맑음, 어제보다 1˚ 높아요

# %%
temp = bs.select('span.todaytemp')
print(temp[0].text)
desc = bs.select('p.cast_txt')
print(desc[0].text)
# Out:
# 6
# 맑음, 어제보다 1˚ 높아요

# %%
def getWeather(city) :    
    url = "https://search.naver.com/search.naver?query="
    url = url + urllib.parse.quote_plus(city + "날씨")
    print(url)
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
    temp = bs.select('span.todaytemp')    
    desc = bs.select('p.cast_txt')    
    #dictionery가 좋은 리턴방식이다.
    return {"temp":temp[0].text, "desc":desc[0].text} #temp가 온도, desc가 어제보다 4도 낮아요.
    #return {"temp":temp[4+7].text, "desc":desc[0].text} #dctionery방식으로 하면, 이런식으로, 수정할때 용이하다.

    #return temp[0].text + "/" + desc[0].text #리턴 값을 문자열로 준다.
print(getWeather("제주도")["desc"])
# Out:
# https://search.naver.com/search.naver?query=%EC%A0%9C%EC%A3%BC%EB%8F%84%EB%82%A0%EC%94%A8
# 맑음, 어제보다 1˚ 높아요

# %%
word = "갑분싸"
url = "https://search.naver.com/search.naver?where=kdic&query="
url = url + urllib.parse.quote_plus(word)
print(url)
# Out:
# https://search.naver.com/search.naver?where=kdic&query=%EA%B0%91%EB%B6%84%EC%8B%B8

# %%
bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")

# %%
output = bs.select('p.txt_box')
print(output[3].text)
# Out:
# 23) 갑분싸 (2018.11.07~2019.06.23) 황철두 (2019.08.04~ TV 출연 목록 KBS 모닝에이드 MC (2010) 내셔널지오그래픽채널 코리아 《마이 펫 TV》- 실제 반려동물이자 고양이 흰돌이와 함께 인터뷰 출연...

# %%
def getQuery(word):
    url = "https://search.naver.com/search.naver?where=kdic&query="
    url = url + urllib.parse.quote_plus(word)
    print(url)
    
    bs = BeautifulSoup(urllib.request.urlopen(url).read(), "html.parser")
    output = bs.select('p.txt_box')
    
    return [node.text for node in output]
    #return output[0].text


print(getQuery("갑분싸"))
print(getQuery("갑분싸")[0])#갑분싸에 대한 0번 인덱스 정의
# Out:
# https://search.naver.com/search.naver?where=kdic&query=%EA%B0%91%EB%B6%84%EC%8B%B8
# ...

# %%
#검색 순위 조작???? 물론, 다음이나 네이버 같은 대기업은 막아 두기는 했다.
#for i in range(10000):
#    getQuery("갑분싸")

# %%
#요건 똑같이 쓸것이다. 무엇을 하던지간에
txt = "1"

print("종료를 원하시면, 0을 입력하시오.")

while(txt!="0"):
    txt = input("->")
    dict = get_answer(txt, 'user01')
    answer = dict['result']['fulfillment']['speech'] 
    intentName = dict['result']['metadata']['intentName']
    
    if intentName == 'query':
        word = dict['result']['parameters']['any']
        text = getQurery(word)
        printts(getQuery(word))

    #첫번째 인텐트
    elif intentName == 'order2' :
        price = {"짜장면":5000, "짬뽕":10000, "탕수육":20000}
        params = dict['result']['parameters']['food_number']
        
        #get함수는 dictionary 값을 받아오는것
        #a{"i":6}이 있으면, a.get(i) == a["i"]와 같다. a["hh"] 면 오류가 나고, a.get("hh")면 None값을 반환한다.
        #a.get("hh", 1)은, 값이 없는 모든 키에 대해, 1값을 넣어준다는 의미이다.
        
        output = [  food.get("number-integer", 1)*price[food["food"]]  for food in params ] 
        printtts(sum(output))
     
     #두번째 인텐트
    elif intentName == 'weather' and  dict['result']['actionIncomplete'] == False :        
            date = dict['result']['parameters']['date']
            geo_city = dict['result']['parameters']['geo-city']                    
            
            info = getWeather(geo_city)            
            print(f"{geo_city} 날씨 정보 : {info['temp']} /  {info['desc']}")
            #print("날씨 ", date, geo_city)       
    else :
        printtts("Bot:" + answer)
# Out:
# 종료를 원하시면, 0을 입력하시오.
# ->0
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dict = get_answer("갑분싸가 뭐야?", "user01")
intentName = dict['result']['metadata']['intentName']
word = dict["result"]["parameters"]["any"]
print(getQuery(word)[0])
# Out:
# https://search.naver.com/search.naver?where=kdic&query=%EA%B0%91%EB%B6%84%EC%8B%B8
#  ‘갑자기 분위기가 싸해진다.’, ‘갑자기 분위기가 싸해지는데’ 등의 뜻을 가지고 있는 신조어이다. ‘갑자기 분위기가 싸해진다’, ‘갑자기 분위기가 싸해지는데’를 줄여 이르는 신조어이다. ‘갑분싸’는...

# %%
#구글에 문자열을 보내면, 구글에서 MP3로 변환해 재생
#영어를 기반으로 해서 자동으로 알아서, 판단해준다.

from gtts import gTTS
text = "안녕"
tts = gTTS(text=text, lang = 'ko')
#==여기까지 하면, 구글 서버를 갔다 오는것==#
tts.save("output.mp3") #로컬에 저장

# %%
ipd.Audio('output.mp3', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
txt = "1"

print("종료를 원하시면, 0을 입력하시오.")

while(txt!="0"):
    txt = input("->")
    dict = get_answer(txt, 'user01')
    answer = dict['result']['fulfillment']['speech'] 
    intentName = dict['result']['metadata']['intentName']
    
    if intentName == 'query':
        word = dict['result']['parameters']['any']
        text = getQuery(word)[0]
        tts = gTTS(text= text, lang = 'ko')
        tts.save('output.mp3')
        print(text)
        ipd.display(ipd.Audio('output.mp3', autoplay = True))
        print(getQuery(word))

    #첫번째 인텐트
    elif intentName == 'order2' :
        price = {"짜장면":5000, "짬뽕":10000, "탕수육":20000}
        params = dict['result']['parameters']['food_number']
        
        #get함수는 dictionary 값을 받아오는것
        #a{"i":6}이 있으면, a.get(i) == a["i"]와 같다. a["hh"] 면 오류가 나고, a.get("hh")면 None값을 반환한다.
        #a.get("hh", 1)은, 값이 없는 모든 키에 대해, 1값을 넣어준다는 의미이다.
        
        output = [  food.get("number-integer", 1)*price[food["food"]]  for food in params ] 
        print(sum(output))
     
     #두번째 인텐트
    elif intentName == 'weather' and  dict['result']['actionIncomplete'] == False :        
            date = dict['result']['parameters']['date']
            geo_city = dict['result']['parameters']['geo-city']                    
            
            info = getWeather(geo_city)            
            print(f"{geo_city} 날씨 정보 : {info['temp']} /  {info['desc']}")
            #print("날씨 ", date, geo_city)       
    else :
        print("Bot:" + answer)
# Out:
# 종료를 원하시면, 0을 입력하시오.
# ->0
# Bot:조금 헷갈리는데요.

# %%
from IPython.core.display import HTML
HTML('<audio autoplay controls> <source src="output.mp3" type="audio/mp3" /> </audio>')
# Out:
# <audio autoplay controls> <source src="output.mp3" type="audio/mp3" /> </audio>

# %%
#"""은 여러줄의 문자열"""
HTML(
    """
    <iframe
        allow="microphone;"
        width="350"
        height="430"
        src="https://console.dialogflow.com/api-client/demo/embedded/ssh_chatbot">
    </iframe>
    """
      )
# Out:
#     <iframe
#         allow="microphone;"
#         width="350"
#         height="430"
#         src="https://console.dialogflow.com/api-client/demo/embedded/ssh_chatbot">
#     </iframe>

# %%
HTML(
"""<iframe id="mainFrame" name="mainFrame" allowfullscreen="true" src="/PostView.nhn?blogId=winsweet&amp;logNo=221284278866&amp;from=search&amp;redirect=Log&amp;widgetTypeCall=true&amp;topReferer=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fsm%3Dtop_hty%26fbm%3D1%26ie%3Dutf8%26query%3D%25EB%2584%25A4%25EC%259D%25B4%25EB%25B2%2584%2Bhtml&amp;directAccess=false" scrolling="auto" onload="oFramesetTitleController.start(self.frames['mainFrame'], self, sTitle);oFramesetTitleController.onLoadFrame();oFramesetUrlController.start(self.frames['mainFrame']);oFramesetUrlController.onLoadFrame()"></iframe>"""
)
# Out:
# C:\Users\student\Anaconda3\envs\py36\lib\site-packages\IPython\core\display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="mainFrame" name="mainFrame" allowfullscreen="true" src="/PostView.nhn?blogId=winsweet&amp;logNo=221284278866&amp;from=search&amp;redirect=Log&amp;widgetTypeCall=true&amp;topReferer=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fsm%3Dtop_hty%26fbm%3D1%26ie%3Dutf8%26query%3D%25EB%2584%25A4%25EC%259D%25B4%25EB%25B2%2584%2Bhtml&amp;directAccess=false" scrolling="auto" onload="oFramesetTitleController.start(self.frames['mainFrame'], self, sTitle);oFramesetTitleController.onLoadFrame();oFramesetUrlController.start(self.frames['mainFrame']);oFramesetUrlController.onLoadFrame()"></iframe>

# %%
#우리가 만든 서버에 접속
url = "http://127.0.0.1:3000/weather?city=%EC%B6%98%EC%B2%9C"
res = requests.get(url)
html = res.text
print(html)
# Out:
# {
#   "desc": "\ub9d1\uc74c, \uc5b4\uc81c\ubcf4\ub2e4 3\u02da \ub192\uc544\uc694",
#   "temp": "1"
# }

# %%
#내가 만든 코드가 아무 문제 없다는것을 검증하기 위한 함수
def processDialog(req) :
    
    answer = req['queryResult']['fulfillmentText']
    intentName = req['queryResult']['intent']['displayName'] 
    
    if intentName == 'query' :
        word = req["queryResult"]['parameters']['any'] 
        text = getQuery(word)[0]                
        res = {'fulfillmentText': text}  
        
    elif  intentName == 'order2' :
        price = {"짜장면":5000, "짬뽕":10000, "탕수육":20000}
        params = req['queryResult']['parameters']['food_number']        
        output = [  food.get("number-integer", 1)*price[food["food"]]  for food in params ] 
        res = {'fulfillmentText': sum(output)}  
    elif intentName == 'weather'  :        
        date = req['queryResult']['parameters']['date']
        geo_city = req['queryResult']['parameters']['geo-city']                                
        info = getWeather(geo_city)  
        res = {'fulfillmentText': f"{geo_city} 날씨 정보 : {info['temp']} /  {info['desc']}"}  
    else :
        res = {'fulfillmentText': answer}           
        
    return res

# %%
#딕셔너리는 읽을때, 없으면 문제가 되지만, 쓸때는 있으면 덮어쓰기가 되고, 없으면 만든다.
sessid = "kim34"

datas = {}
datas[sessid] = [10, 20, 30]


sessid = "lee12"
datas = {}
datas[sessid] = [-10, 5, 4]

# %%
#둘중 하나 무엇을 써도 된다.
#sessid = "kim34"
#datas[sessid]["win"] = datas[sessid]["win"] + 1

#datas[sessd].win = datas[sessid].win + 1

#datas[sessid] = {"Win" : 0, "lose" : 0}

# %%
class User:
    def __init__(self):
        self.win = 0
        self.lose = 0
        self.draw = 0
    
p1 = User()
p2 = User()

p1.win = 3
p1.lose - 5

p2.win = 7
p2.lose = 4

datas[sessid] = p1

print(datas)
print(datas[sessid].win) #sessid 유저가 가지고 있는 어떤 변수인지
# Out:
# {'lee12': <__main__.User object at 0x000001D1BAD789E8>}
# 3
